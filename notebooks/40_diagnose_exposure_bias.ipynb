# %% [markdown]
# # Exposure-Bias Diagnostic
# Compute Δ(k) on a run directory produced by the training notebook or CLI.

# %%
from pathlib import Path
import sys

project_root = Path.cwd().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

dbutils.widgets.text("run_dir", "experiments/runs/<replace_with_run_dir>")
dbutils.widgets.text("split", "val")
dbutils.widgets.text("k_values", "8 16 32 64")
dbutils.widgets.text("max_examples", "200")

# %%
from scripts.diagnose_exposure_bias import run_diagnostic

run_dir = dbutils.widgets.get("run_dir")
split = dbutils.widgets.get("split")
k_values = [int(x) for x in dbutils.widgets.get("k_values").split()]
max_examples_raw = dbutils.widgets.get("max_examples").strip()
max_examples = int(max_examples_raw) if max_examples_raw else None

result = run_diagnostic(
    run_dir=run_dir,
    split=split,
    k_values=k_values,
    max_examples=max_examples,
)
result
