# %% [markdown]
# # Experiment Summary
# Inspect the leaderboard produced by completed runs.

# %%
from pathlib import Path
import pandas as pd

project_root = Path.cwd().resolve().parent
leaderboard_path = project_root / "experiments" / "summaries" / "leaderboard.csv"
if leaderboard_path.exists():
    display(pd.read_csv(leaderboard_path))
else:
    print(f"No leaderboard found at {leaderboard_path}")
