# %% [markdown]
# # Setup and Config
# Install dependencies, restart Python if needed, and inspect the chosen experiment config.

# %%
# %pip install pyyaml rouge-score mlflow transformers pandas tqdm

# %%
# %restart_python

# %%
from pathlib import Path
import sys
import yaml

project_root = Path.cwd().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

dbutils.widgets.text("experiment_config", "configs/experiment/curriculum_linear.yaml")
experiment_config = dbutils.widgets.get("experiment_config")
config_path = project_root / experiment_config
with config_path.open("r", encoding="utf-8") as handle:
    print(handle.read())
